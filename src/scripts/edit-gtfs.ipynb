# %%
import gtfs_kit as gk
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/sandbox/lib/python3.9/site-packages/geopandas/_compat.py:112: UserWarning: The Shapely GEOS version (3.9.1-CAPI-1.14.2) is incompatible with the GEOS version PyGEOS was compiled with (3.10.3-CAPI-1.16.1). Conversions between both will be slow.
#   warnings.warn(

# %%
new_routes = [
    "870","871","822","849","845","851","892","808","741","743","388","893","874","886","825","809","833","881","817","851","662","990","987","831","865","709","678","785","702","778","922","925","665","349","311","686","951","869","277","665","669","254","915","928","901","014","104","201","448","435","010","603","626","157","605","229","012","518","519",
]

# %%
path = 'data/gtfs-novo.zip'

# %%
feed = gk.read_feed(path, dist_units='km')
feed.describe()
# Out:
#                            indicator  \
# 0                           agencies
# 1                           timezone
# 2                         start_date
# 3                           end_date
# 4                         num_routes
# 5                          num_trips
# 6                          num_stops
# 7                         num_shapes
# 8                        sample_date
# 9   num_routes_active_on_sample_date
# 10   num_trips_active_on_sample_date
# 11   num_stops_active_on_sample_date
#
#                                                 value
# 0   [Intersul, Internorte, Transcarioca, Santa Cru...
# 1                                   America/Sao_Paulo
# 2                                            20220716
# 3                                            20221231
# 4                                                 412
# 5                                                7486
# 6                                                8997
# ...

# %%
a = feed.routes
a = a[~a['route_short_name'].str.contains('SV')]
feed.routes = a

# %%
a
# Out:
#        route_id agency_id route_short_name                   route_long_name  \
# 1          84be     22005              833         Manguariba - Campo Grande
# 2          bosw     22003           LECD52           Cascadura - Coelho Neto
# 3          btwr     22005              830          Pedregoso - Campo Grande
# 4    O0842AAA0A     22005              842          Paciência - Campo Grande
# 5          hvak     22003              678            Méier - Vila Valqueire
# ..          ...       ...              ...                               ...
# 407  O0046CAA0A     22005           LECD46            Sepetiba - Coelho Neto
# 408  O0047CAA0A     22005           LECD47   Campo Grande - Terminal Sulacap
# 409  O0048CAA0A     22005           LECD48  West Shopping - Terminal Sulacap
# 410  O0049CAA0A     22002           LECD49             Gávea (PUC) - Castelo
# 411  O0050CAA0A     22002           LECD50    Vila Isabel - Praça Saens Peña
#
# ...

# %%
routes = feed.routes['route_short_name'].unique()

# %%
inter = set(new_routes).intersection(set(routes))

# %%
inter
# Out:
# {'010',
#  '014',
#  '104',
#  '201',
#  '229',
#  '254',
#  '277',
#  '311',
#  '349',
#  '388',
#  '435',
#  '448',
#  '603',
#  '626',
#  '665',
#  '669',
#  '678',
#  '709',
#  '741',
#  '743',
#  '778',
#  '809',
#  '822',
#  '825',
#  '833',
#  '845',
#  '849',
#  '851',
#  '865',
#  '870',
#  '871',
#  '892',
#  '893',
#  '901',
#  '915',
#  '922',
#  '925',
#  '928',
#  '951'}

# %%
set(new_routes).difference(inter)
# Out:
# {'012',
#  '157',
#  '518',
#  '519',
#  '605',
#  '662',
#  '686',
#  '702',
#  '785',
#  '808',
#  '817',
#  '831',
#  '869',
#  '874',
#  '881',
#  '886',
#  '987',
#  '990'}

# %%
routes.sort()

# %%
routes
# Out:
# array(['006', '007', '010', '014', '100', '104', '105', '107', '108',
#        '110', '112', '117', '133', '181', '201', '2018', '202', '209',
#        '210', '2111', '2112', '2114', '2145', '217', '220', '229', '2303',
#        '2305', '2307', '2308', '2309', '2310', '232', '2332', '2334',
#        '2335', '2336', '2337', '2338', '2339', '2342', '2343', '2344',
#        '2345', '238', '2380', '2381', '2383', '239', '247', '249', '254',
#        '265', '275', '277', '2801', '2802', '2803', '2804', '292', '296',
#        '298', '300', '302', '306', '309', '311', '312', '313', '315',
#        '321', '323', '324', '325', '326', '327', '328', '329', '335',
#        '335 SR', '338', '341', '342', '343', '348', '349', '350', '353',
#        '355', '361', '362', '363', '368', '369', '371', '378', '379',
#        '380', '383', '384', '385', '386', '388', '389', '390', '393',
#        '395', '397', '399', '409', '410', '415', '416', '422', '426',
# ...
